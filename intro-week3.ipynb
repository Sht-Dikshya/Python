# %% [markdown]
# # **Data Analysis with Pandas**
#
# **Import and use Pandas**

# %%
import pandas as pd

#create new series
number_series= pd.Series([1,2,3,4])
print(number_series)

# Create a new data frame
user_data_dict = {
    'Name': ['Ram', 'Hari','Smriti', 'Dikshya', 'Roman'],
    'Age': [24, 30, 21, 22, 23],
    'Address': ['Kathmandu', 'Bhaktapur', 'Bhaktapur', 'Thimi','Balkumari']
}
user_data = pd.DataFrame(user_data_dict)
user_data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#       Name  Age    Address
# 0      Ram   24  Kathmandu
# 1     Hari   30  Bhaktapur
# 2   Smriti   21  Bhaktapur
# 3  Dikshya   22      Thimi
# 4    Roman   23  Balkumari

# %% [markdown]
# # **Read data from csv**

# %%
import pandas as pd
from IPython.display import display
student_csv_data= pd.read_csv('data/student-dataset.csv')
display (student_csv_data.head())     # head le top ko 5 ota row # print garyo ki tabular form didaina 
student_csv_data.tail()     #tail le last ko 5 ota row
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 3             3.2             5.0                 5                 2.0
# 4             3.4             1.0                 4                 4.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
# 3                 4
# 4                 5
#       id               name               nationality         city  latitude  \
# 302  302        Austin Haas  United States of America     Columbus     39.96
# 303  303    Madison Fithian  United States of America  Los Angeles     34.05
# 304  304  Zachary Mulvahill  United States of America  Los Angeles     34.05
# 305  305   Eliana Michelsen  United States of America      Oakland     37.80
# 306  306    Dane Whittemore                    Canada      Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 302     -83.00      M           NaN   20            3.6         3.7
# 303    -118.24      F           NaN   20            3.6         3.9
# 304    -118.24      M           NaN   20            3.2         3.4
# 305    -122.27      F           NaN   23            3.0         2.8
# 306     -79.42      M           NaN   21            3.8         3.2
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 302             3.1             5.0                 4                 5.0
# 303             4.0             5.0                 5                 5.0
# 304             3.9             5.0                 5                 5.0
# 305             2.9             5.0                 4                 4.0
# 306             4.0             5.0                 5                 4.0
#
#      refletter.rating
# 302                 5
# 303                 3
# 304                 3
# 305                 5
# 306                 5

# %%
import pandas as pd
student_csv_data= pd.read_csv('data/student-dataset.csv')
student_csv_data.head(10)
# Out:
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 3   3   Natasha Yarusso  United States of America        Castro Valley
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
# 6   6        Joey Abreu                     China             Shenyang
# 7   7    Preston Suarez                    Brazil            São Paulo
# 8   8          Lee Dong               Philippines               Manila
# 9   9     Maa'iz al-Dia                    Turkey             Istanbul
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
# 5     39.77     -86.16      F           NaN   21            3.4         3.1
# 6     41.79     123.43      M           NaN   22            3.7         3.9
# 7    -23.47     -46.67      M           NaN   22            3.8         3.7
# 8     14.60     120.98      F           NaN   24            3.9         3.6
# 9     41.02      28.96      M           NaN   22            2.4         2.8
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 3             3.2             5.0                 5                 2.0
# 4             3.4             1.0                 4                 4.0
# 5             3.7             5.0                 2                 4.0
# 6             3.6             2.0                 5                 5.0
# 7             3.6             2.0                 5                 5.0
# 8             3.2             2.0                 4                 3.0
# 9             3.8             3.0                 5                 5.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
# 3                 4
# 4                 5
# 5                 4
# 6                 5
# 7                 4
# 8                 5
# 9                 4

# %% [markdown]
# # **Save Pandas Dataframe to csv, excel, and JSON file**

# %%
import pandas as pd

# create new Data Frame

user_data = pd.DataFrame({
    'Name': ['Ram', 'Hari','Smriti', 'Dikshya'],
    'Age': [24, 30, 21, 22],
    'Address': ['Kathmandu', 'Bhaktapur', 'Bhaktapur', 'Thimi']
})
user_data.to_csv ('./data/user_data.csv')
user_data.to_excel ('./data/user_data.xlsx')
user_data.to_json ('./data/user_data.json')

# %% [markdown]
# # **Basic Data Exploration**
#
# **Data Inspection**

# %%
import pandas as pd
from IPython.display import display

students= pd.read_csv ('data/student-dataset.csv')
display("Shape:",students.shape)
display ("Info:",students.info())  
students.describe()
# Out:
# 'Shape:'
# (307, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  307 non-null    int64
#  1   name                307 non-null    object
#  2   nationality         307 non-null    object
#  3   city                307 non-null    object
#  4   latitude            307 non-null    float64
#  5   longitude           307 non-null    float64
#  6   gender              307 non-null    object
#  7   ethnic.group        0 non-null      float64
#  8   age                 307 non-null    int64
#  9   english.grade       307 non-null    float64
#  10  math.grade          307 non-null    float64
#  11  sciences.grade      307 non-null    float64
#  12  language.grade      307 non-null    float64
#  13  portfolio.rating    307 non-null    int64
#  14  coverletter.rating  307 non-null    float64
#  15  refletter.rating    307 non-null    int64
# dtypes: float64(8), int64(4), object(4)
# memory usage: 38.5+ KB
# 'Info:'
# None
#                id    latitude   longitude  ethnic.group         age  \
# count  307.000000  307.000000  307.000000           0.0  307.000000
# mean   153.000000   32.863388  -64.539121           NaN   21.964169
# std     88.767487   13.498582   81.249146           NaN    1.248013
# min      0.000000  -33.450000 -123.130000           NaN   19.000000
# 25%     76.500000   32.720000 -118.240000           NaN   21.000000
# 50%    153.000000   34.390000  -99.140000           NaN   22.000000
# 75%    229.500000   38.960000  -73.855000           NaN   23.000000
# max    306.000000   59.890000  139.750000           NaN   26.000000
#
#        english.grade  math.grade  sciences.grade  language.grade  \
# count     307.000000  307.000000      307.000000      307.000000
# mean        3.369707    3.414332        3.446580        4.396417
# std         0.538724    0.476839        0.509081        0.996474
# min         1.500000    2.100000        1.400000        1.000000
# 25%         3.100000    3.100000        3.200000        4.000000
# 50%         3.500000    3.500000        3.600000        5.000000
# 75%         3.800000    3.800000        3.800000        5.000000
# max         4.000000    4.000000        4.000000        5.000000
#
#        portfolio.rating  coverletter.rating  refletter.rating
# count        307.000000          307.000000        307.000000
# mean           3.986971            4.110749          4.188925
# std            0.928749            0.823936          0.842193
# min            1.000000            1.000000          1.000000
# 25%            3.500000            4.000000          4.000000
# 50%            4.000000            4.000000          4.000000
# 75%            5.000000            5.000000          5.000000
# max            5.000000            5.000000          5.000000

# %% [markdown]
# # **Data Selection and Indexing in Pandas**
#
# - Basic Indexing
#
# - Label-based Indexing (.loc[])
#
# - Integer-Label-based Indexing (.iloc[])
#
# - Single Value Access (.at[], .iat[])

# %% [markdown]
# # ***Basic Indexing***

# %%
# # Basic Indexing
print(students['name'])        # Single column as a series
new_std_data= students[['id', 'name', 'nationality']]
print (new_std_data)            # multiple columns as a DataFrame

# # # Slicing rows
first_10_rows= students[0:10]
print(first_10_rows)    #only 10 rows (dataframe)
last_five_rows= students[302:].copy()
print(last_five_rows)       #rows from index 302 to last index(dataframe) can do [302:307] also
# Out:
# 0              Kiana Lor
# 1         Joshua Lonaker
# 2          Dakota Blanco
# 3        Natasha Yarusso
# 4         Brooke Cazares
#              ...
# 302          Austin Haas
# 303      Madison Fithian
# 304    Zachary Mulvahill
# 305     Eliana Michelsen
# 306      Dane Whittemore
# Name: name, Length: 307, dtype: object
#       id               name               nationality
# 0      0          Kiana Lor                     China
# 1      1     Joshua Lonaker  United States of America
# 2      2      Dakota Blanco  United States of America
# 3      3    Natasha Yarusso  United States of America
# 4      4     Brooke Cazares                    Brazil
# ..   ...                ...                       ...
# 302  302        Austin Haas  United States of America
# 303  303    Madison Fithian  United States of America
# 304  304  Zachary Mulvahill  United States of America
# 305  305   Eliana Michelsen  United States of America
# 306  306    Dane Whittemore                    Canada
#
# [307 rows x 3 columns]
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 3   3   Natasha Yarusso  United States of America        Castro Valley
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
# 6   6        Joey Abreu                     China             Shenyang
# 7   7    Preston Suarez                    Brazil            São Paulo
# 8   8          Lee Dong               Philippines               Manila
# 9   9     Maa'iz al-Dia                    Turkey             Istanbul
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
# 5     39.77     -86.16      F           NaN   21            3.4         3.1
# 6     41.79     123.43      M           NaN   22            3.7         3.9
# 7    -23.47     -46.67      M           NaN   22            3.8         3.7
# 8     14.60     120.98      F           NaN   24            3.9         3.6
# 9     41.02      28.96      M           NaN   22            2.4         2.8
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 3             3.2             5.0                 5                 2.0
# 4             3.4             1.0                 4                 4.0
# 5             3.7             5.0                 2                 4.0
# 6             3.6             2.0                 5                 5.0
# 7             3.6             2.0                 5                 5.0
# 8             3.2             2.0                 4                 3.0
# 9             3.8             3.0                 5                 5.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
# 3                 4
# 4                 5
# 5                 4
# 6                 5
# 7                 4
# 8                 5
# 9                 4
#       id               name               nationality         city  latitude  \
# 302  302        Austin Haas  United States of America     Columbus     39.96
# 303  303    Madison Fithian  United States of America  Los Angeles     34.05
# 304  304  Zachary Mulvahill  United States of America  Los Angeles     34.05
# 305  305   Eliana Michelsen  United States of America      Oakland     37.80
# 306  306    Dane Whittemore                    Canada      Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 302     -83.00      M           NaN   20            3.6         3.7
# 303    -118.24      F           NaN   20            3.6         3.9
# 304    -118.24      M           NaN   20            3.2         3.4
# 305    -122.27      F           NaN   23            3.0         2.8
# 306     -79.42      M           NaN   21            3.8         3.2
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 302             3.1             5.0                 4                 5.0
# 303             4.0             5.0                 5                 5.0
# 304             3.9             5.0                 5                 5.0
# 305             2.9             5.0                 4                 4.0
# 306             4.0             5.0                 5                 4.0
#
#      refletter.rating
# 302                 5
# 303                 3
# 304                 3
# 305                 5
# 306                 5

# %% [markdown]
# # ***Label-based Indexing (.loc[])***
#
# - .loc([]) is used for selecting rows and columns by labels
# - We can use single labels, lists of labels, or slices of labelss

# %%
# Selecting rows based on label
students= pd.read_csv('data/student-dataset.csv')
first_row= students.loc[1]
first_two_rows= students.loc[0:1]
print(first_row)        #Row with label 1 (index) labels can be string, data, etc.
print(first_two_rows)   # Rows with labels 0 to 1

## Selecting specific rows to columns
first_five_stds_with_name_to_nationality= students.loc[0:4, 'name':'nationality']
print(first_five_stds_with_name_to_nationality)

# select only particular rows and columns
first_and_second_row_with_name_and_gender= students.loc[[5,20], ['name', 'gender']]
# rows 6th and 21th, columns name and gender
first_and_second_row_with_name_and_gender
# Out:
# id                                           1
# name                            Joshua Lonaker
# nationality           United States of America
# city                             Santa Clarita
# latitude                                 34.39
# longitude                              -118.54
# gender                                       M
# ethnic.group                               NaN
# age                                         22
# english.grade                              2.9
# math.grade                                 3.2
# sciences.grade                             3.6
# language.grade                             5.0
# portfolio.rating                             5
# coverletter.rating                         4.0
# refletter.rating                             5
# Name: 1, dtype: object
#    id            name               nationality           city  latitude  \
# 0   0       Kiana Lor                     China         Suzhou     31.31
# 1   1  Joshua Lonaker  United States of America  Santa Clarita     34.39
#
#    longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     120.62      F           NaN   22            3.5         3.7
# 1    -118.54      M           NaN   22            2.9         3.2
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
#
#    refletter.rating
# 0                 4
# 1                 5
#               name               nationality
# 0        Kiana Lor                     China
# 1   Joshua Lonaker  United States of America
# 2    Dakota Blanco  United States of America
# 3  Natasha Yarusso  United States of America
# 4   Brooke Cazares                    Brazil
#                 name gender
# 5   Rochelle Johnson      F
# 20        Rojesh Her      M

# %% [markdown]
# # ***Integer-location Based Indexing***
# - .iloc[] is **used** for selecting rows and columns by integer index positions
# - Similarly to .loc[], we can use single integers, lists of integers, or slices

# %%
# Selecting rows based on index positions
print(students.iloc[1])                            #Second row (index1)
print(students.iloc[0:3])                          #Rows at index positions 0 to 2

# Selecting specific rows and columns
print(students.iloc[0:2,0:2])                       #Rows 0 to 2, column 0 to 2
print(students.iloc[[0,2],[0,2]])
# Out:
# id                                           1
# name                            Joshua Lonaker
# nationality           United States of America
# city                             Santa Clarita
# latitude                                 34.39
# longitude                              -118.54
# gender                                       M
# ethnic.group                               NaN
# age                                         22
# english.grade                              2.9
# math.grade                                 3.2
# sciences.grade                             3.6
# language.grade                             5.0
# portfolio.rating                             5
# coverletter.rating                         4.0
# refletter.rating                             5
# Name: 1, dtype: object
#    id            name               nationality           city  latitude  \
# 0   0       Kiana Lor                     China         Suzhou     31.31
# 1   1  Joshua Lonaker  United States of America  Santa Clarita     34.39
# 2   2   Dakota Blanco  United States of America        Oakland     37.80
#
#    longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     120.62      F           NaN   22            3.5         3.7
# 1    -118.54      M           NaN   22            2.9         3.2
# 2    -122.27      F           NaN   22            3.9         3.8
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
#    id            name
# 0   0       Kiana Lor
# 1   1  Joshua Lonaker
#    id               nationality
# 0   0                     China
# 2   2  United States of America

# %% [markdown]
# # ***Single Value Access(.at[] and  .iat[])***
#
# - .at[] is used for accessing a single scalar value by label.
# - .iat[] is for accessing by index position.

# %%
# Using .at[] to access single value by label
print(students.at[1,'name'])                # Value in row 2, column 'name'

# Using .iat[] to access single value by position
print(students.iat[5, 1])                   #Value in row 6, column 1
# Out:
# Joshua Lonaker
# Rochelle Johnson

# %% [markdown]
# ## *Create new Dataframe from the students data, with name, nationality and grades in English and maths*

# %%
students.loc[0:20,['name','nationality','english.grade','math.grade']]
# Out:
#                  name               nationality  english.grade  math.grade
# 0           Kiana Lor                     China            3.5         3.7
# 1      Joshua Lonaker  United States of America            2.9         3.2
# 2       Dakota Blanco  United States of America            3.9         3.8
# 3     Natasha Yarusso  United States of America            3.3         2.8
# 4      Brooke Cazares                    Brazil            3.7         2.6
# 5    Rochelle Johnson  United States of America            3.4         3.1
# 6          Joey Abreu                     China            3.7         3.9
# 7      Preston Suarez                    Brazil            3.8         3.7
# 8            Lee Dong               Philippines            3.9         3.6
# 9       Maa'iz al-Dia                    Turkey            2.4         2.8
# 10     Maja Nicholson  United States of America            3.4         3.5
# 11       Sasha Jansen  United States of America            1.7         4.0
# 12  Alexander Sherman  United States of America            3.8         3.6
# 13      Edgar Sanchez                    Mexico            3.7         3.5
# 14       Kolbi Strunk  United States of America            3.2         3.9
# 15      Brittany Sath                     Japan            4.0         3.9
# 16       Meggan Smith  United States of America            2.9         3.4
# 17     Ericka Arreola                    Mexico            3.1         3.5
# 18         David Pulc                    Canada            3.9         2.9
# 19        Kyle Luckey  United States of America            3.7         3.9
# 20         Rojesh Her                     Japan            3.8         3.6

# %% [markdown]
# # *Select first 100 rows and 'name','ethinic group', columns from the given students data*

# %%
students.loc[0:100,['name','ethnic.group']]
# Out:
#                   name  ethnic.group
# 0            Kiana Lor           NaN
# 1       Joshua Lonaker           NaN
# 2        Dakota Blanco           NaN
# 3      Natasha Yarusso           NaN
# 4       Brooke Cazares           NaN
# ..                 ...           ...
# 96      Mateo Cisneros           NaN
# 97       William Pablo           NaN
# 98   Jason Hundsdorfer           NaN
# 99       Antonio Desai           NaN
# 100     Rachel Bakeman           NaN
#
# [101 rows x 2 columns]

# %% [markdown]
# # **Filtering**
#
# - Logical operators(>,<,==,!=)
# - Multiple logical operators (&(AND) and |(OR))
# - Str ancessor, Isin, contains, between, startWith
# - Tilde(~)
# - Query
# - Nlargest and nsmallest
# - Loc and iloc

# %% [markdown]
# # ***Logical Operators***

# %%
from IPython.display import display

# Students with grade less than 2
stds_failed_in_math= students[students['math.grade']<2.3]
display('Failed:',stds_failed_in_math)
stds_passed_in_english= students[students['english.grade']>3.9]
display('Passed:',stds_passed_in_english)

# select chinese students with grade in english greater than 3.6
stds_in_china = students[(students['nationality'] == 'China') & (students['english.grade'] > 3.8)]
display('Chinese Students:', stds_in_china)
# Out:
# 'Failed:'
#       id                  name               nationality         city  \
# 51    51           Hannah Uren  United States of America  Los Angeles
# 59    59      Shuraih el-Karim                  Pakistan     Khalabat
# 73    73  Aurelia Davis Ingham  United States of America    Roseville
# 133  133          Andrew Kirin  United States of America       Odessa
# 272  272       William Tierney  United States of America     New York
# 288  288      Weldon Hightower  United States of America     New York
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 51      34.05    -118.24      F           NaN   22            3.2         2.2
# 59      34.06      72.89      M           NaN   22            3.1         2.1
# 73      38.75    -121.29      F           NaN   22            3.8         2.2
# 133     31.85    -102.37      M           NaN   25            3.8         2.2
# 272     40.71     -74.01      M           NaN   21            3.8         2.1
# 288     40.71     -74.01      M           NaN   20            2.6         2.1
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 51              3.5             5.0                 5                 3.0
# 59              2.3             4.0                 4                 4.0
# 73              3.7             5.0                 4                 5.0
# 133             3.0             5.0                 3                 2.0
# 272             3.0             5.0                 3                 4.0
# 288             3.2             5.0                 4                 5.0
#
#      refletter.rating
# 51                  5
# 59                  4
# 73                  5
# 133                 3
# 272                 4
# 288                 5
# 'Passed:'
#       id                 name               nationality              city  \
# 15    15        Brittany Sath                     Japan             Tokyo
# 68    68      Gabrielle Smith       Korea (Republic of)             Seoul
# 120  120        Meghan Arnold        Russian Federation  Saint Petersburg
# 123  123       Gareth Newkirk  United States of America       Los Angeles
# 140  140         Faviola Soto                    Mexico          Cortazar
# 174  174        Andrew Bishop  United States of America       Los Angeles
# 181  181  Addie Villavicencio  United States of America          San Jose
# 195  195         Joshua Mesan  United States of America          San Jose
# 197  197           Troy White  United States of America          New York
# 201  201          Tyler Kibel  United States of America         Santa Ana
# 227  227    Patricia Rockhold  United States of America     San Francisco
# 229  229     Katherine Beatty  United States of America       Los Angeles
# 240  240        Rylee Onstott  United States of America       Los Angeles
# 246  246    Vittoria Faulkner  United States of America           Chicago
# 268  268     Bryant Ronquillo                    Mexico    Aguascalientes
# 269  269         Garrett Heim  United States of America            Mobile
# 275  275       Blake Loughran  United States of America     San Francisco
# 286  286      Michael Griffin  United States of America          New York
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 15      35.69     139.75      F           NaN   21            4.0         3.9
# 68      37.60     126.98      F           NaN   23            4.0         3.0
# 120     59.89      30.26      F           NaN   24            4.0         3.9
# 123     34.05    -118.24      M           NaN   21            4.0         3.2
# 140     20.48    -100.93      F           NaN   19            4.0         3.8
# 174     34.05    -118.24      M           NaN   22            4.0         3.7
# 181     37.34    -121.89      F           NaN   20            4.0         3.5
# 195     37.34    -121.89      M           NaN   24            4.0         3.8
# 197     40.71     -74.01      M           NaN   22            4.0         3.6
# 201     33.75    -117.87      M           NaN   24            4.0         3.2
# 227     37.77    -122.42      F           NaN   21            4.0         3.5
# 229     34.05    -118.24      F           NaN   19            4.0         2.4
# 240     34.05    -118.24  other           NaN   21            4.0         3.8
# 246     41.85     -87.65      F           NaN   22            4.0         3.6
# 268     21.88    -102.30      M           NaN   20            4.0         3.2
# 269     30.69     -88.04      M           NaN   20            4.0         3.2
# 275     37.77    -122.42      M           NaN   21            4.0         3.0
# 286     40.71     -74.01      M           NaN   21            4.0         4.0
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 15              3.7             3.0                 5                 3.0
# 68              2.8             3.0                 2                 2.0
# 120             3.3             3.0                 5                 3.0
# 123             3.9             5.0                 4                 5.0
# 140             3.9             3.7                 5                 5.0
# 174             3.8             5.0                 3                 3.0
# 181             3.2             5.0                 5                 5.0
# 195             3.7             5.0                 5                 4.0
# 197             3.4             5.0                 4                 4.0
# 201             3.8             5.0                 5                 3.0
# 227             3.4             5.0                 5                 4.0
# 229             3.9             5.0                 4                 5.0
# 240             3.8             5.0                 5                 5.0
# 246             2.5             5.0                 5                 4.0
# 268             3.5             4.0                 3                 5.0
# 269             3.1             5.0                 4                 4.0
# 275             3.4             5.0                 4                 3.0
# 286             4.0             5.0                 3                 5.0
#
#      refletter.rating
# 15                  5
# 68                  4
# 120                 3
# 123                 4
# 140                 4
# 174                 3
# 181                 4
# 195                 5
# 197                 5
# 201                 4
# 227                 5
# 229                 4
# 240                 3
# 246                 4
# 268                 3
# 269                 5
# 275                 4
# 286                 5
# 'Chinese Students:'
#       id           name nationality       city  latitude  longitude gender  \
# 21    21    David Weber       China     Peking     39.93     116.39      M
# 218  218  Nicole Patria       China  Chongqing     29.56     106.55      F
#
#      ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 21            NaN   20            3.9         3.9             3.9
# 218           NaN   24            3.9         3.3             3.0
#
#      language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 21              2.0                 3                 4.0                 5
# 218             2.0                 3                 5.0                 5

# %% [markdown]
# # ***Multiple Logical OPerators***

# %%
from IPython.display import display

# students having grades greater than 3.5. in all subjects
topper_students = students[(students['math.grade'] > 3.8) & (students['sciences.grade'] > 3.8)]
topper_students.head()

#students with grade than 3.8 in at least one subject

average_students= students[(students['english.grade'] >3.8) | (students['math.grade'] >3.8)| (students['sciences.grade'] >3.8)]
display (average_students.head())

# find all Indian female students with age greater than 23 and grade in maths greater than 4
Brazilian_female = students[(students['nationality'] == 'Brazil') & (students['gender'] == 'F') & (students['age'] > 23) & (students['math.grade'] > 3)]
display (Brazilian_female)
# Out:
#     id               name               nationality      city  latitude  \
# 2    2      Dakota Blanco  United States of America   Oakland     37.80
# 6    6         Joey Abreu                     China  Shenyang     41.79
# 8    8           Lee Dong               Philippines    Manila     14.60
# 11  11       Sasha Jansen  United States of America   Chicago     41.85
# 12  12  Alexander Sherman  United States of America     Omaha     41.26
#
#     longitude gender  ethnic.group  age  english.grade  math.grade  \
# 2     -122.27      F           NaN   22            3.9         3.8
# 6      123.43      M           NaN   22            3.7         3.9
# 8      120.98      F           NaN   24            3.9         3.6
# 11     -87.65      F           NaN   21            1.7         4.0
# 12     -95.94      M           NaN   20            3.8         3.6
#
#     sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 2              3.2             5.0                 3                 3.0
# 6              3.6             2.0                 5                 5.0
# 8              3.2             2.0                 4                 3.0
# 11             3.6             5.0                 4                 4.0
# 12             3.9             5.0                 4                 4.0
#
#     refletter.rating
# 2                  4
# 6                  5
# 8                  5
# 11                 5
# 12                 5
#       id                   name nationality            city  latitude  \
# 135  135             Ivy Lucero      Brazil       São Paulo    -23.47
# 180  180  Nicole Torres-Valadez      Brazil  Rio de Janeiro    -22.90
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 135     -46.67      F           NaN   24            3.9         3.6
# 180     -43.23      F           NaN   24            3.9         3.1
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 135             3.2             3.0                 4                 4.0
# 180             3.0             1.0                 4                 5.0
#
#      refletter.rating
# 135                 4
# 180                 4

# %% [markdown]
# # ***str, Isin, contains, between, startWith***

# %%
# students name starts with 'J'
stds_with_name_j = students[students.name.str.startswith('J')]
print("Name with J:",stds_with_name_j.head())

stds_with_name_gimmy= students[students.name.str.contains('Gimmy')]
print(stds_with_name_gimmy)

# students with math.grade between 4 and 5
stds_with_name_j= students[students['math.grade'].between(4,5)]
stds_with_name_j.head()

# chinese or american students
C_or_A_students= students[students['nationality'].isin (['China','America'])]
C_or_A_students
# Out:
# Name with J:     id             name               nationality           city  latitude  \
# 1    1   Joshua Lonaker  United States of America  Santa Clarita     34.39
# 6    6       Joey Abreu                     China       Shenyang     41.79
# 38  38  Joshua Galloway  United States of America       New York     40.71
# 42  42   Jesse Williams        Russian Federation         Moscow     55.75
# 71  71     Joseph Smith  United States of America     Sacramento     38.58
#
#     longitude gender  ethnic.group  age  english.grade  math.grade  \
# 1     -118.54      M           NaN   22            2.9         3.2
# 6      123.43      M           NaN   22            3.7         3.9
# 38     -74.01      M           NaN   24            3.3         3.3
# 42      37.62      F           NaN   21            3.9         3.4
# 71    -121.49      M           NaN   21            3.7         3.7
#
#     sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 1              3.6             5.0                 5                 4.0
# 6              3.6             2.0                 5                 5.0
# 38             3.6             5.0                 4                 5.0
# 42             2.6             4.0                 4                 4.0
# 71             2.8             5.0                 5                 4.0
#
#     refletter.rating
# 1                  5
# 6                  5
# 38                 5
# 42                 5
# 71                 4
# Empty DataFrame
# Columns: [id, name, nationality, city, latitude, longitude, gender, ethnic.group, age, english.grade, math.grade, sciences.grade, language.grade, portfolio.rating, coverletter.rating, refletter.rating]
# Index: []
#       id              name nationality       city  latitude  longitude gender  \
# 0      0         Kiana Lor       China     Suzhou     31.31     120.62      F
# 6      6        Joey Abreu       China   Shenyang     41.79     123.43      M
# 21    21       David Weber       China     Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China       Hebi     35.90     114.19      M
# 61    61      Colin Lemont       China   Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China      Wuhan     30.58     114.27      M
# 162  162    Rebecca Ah Fat       China   Tangshan     37.33     114.70      F
# 176  176          Surya Ky       China   Tangshan     37.33     114.70      M
# 189  189          Emma Kim       China   Hengshui     37.73     115.70      F
# 194  194  Chue Fue Richter       China    Qiqihar     47.34     123.97      M
# 214  214    Christian Chow       China     Handan     36.57     114.53      M
# 218  218     Nicole Patria       China  Chongqing     29.56     106.55      F
# 232  232    Anna Yoshimura       China     Rizhao     35.39     119.55      F
#
#      ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 0             NaN   22            3.5         3.7             3.1
# 6             NaN   22            3.7         3.9             3.6
# 21            NaN   20            3.9         3.9             3.9
# 24            NaN   23            2.8         3.5             3.5
# 61            NaN   21            3.6         4.0             3.1
# 76            NaN   21            3.5         3.9             3.4
# 162           NaN   22            1.8         3.8             4.0
# 176           NaN   21            3.7         4.0             3.8
# 189           NaN   22            2.8         3.9             3.8
# 194           NaN   23            3.0         3.6             1.4
# 214           NaN   21            2.6         3.9             3.4
# 218           NaN   24            3.9         3.3             3.0
# 232           NaN   20            3.5         3.8             3.9
#
#      language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 0               1.0                 4                 4.0                 4
# 6               2.0                 5                 5.0                 5
# 21              2.0                 3                 4.0                 5
# 24              4.0                 5                 4.0                 4
# 61              4.0                 4                 5.0                 4
# 76              4.0                 4                 4.0                 5
# 162             4.0                 4                 3.0                 4
# 176             4.0                 4                 4.0                 5
# 189             2.0                 4                 4.0                 4
# 194             4.0                 5                 3.0                 4
# 214             4.0                 5                 5.0                 5
# 218             2.0                 3                 5.0                 5
# 232             4.0                 5                 5.0                 2

# %% [markdown]
# # ***Tilde(~)***

# %%
# Filter students with age less than 20 and greater than 24

stds_with_age_less_than_20= students[~students['age'].isin([20,24])]
stds_with_age_less_than_20.head()
# Out:
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
# 5     39.77     -86.16      F           NaN   21            3.4         3.1
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 4             3.4             1.0                 4                 4.0
# 5             3.7             5.0                 2                 4.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
# 4                 5
# 5                 4

# %% [markdown]
# # ***Query***

# %%
# Filter students with age above 25 and gender is 'male'

query_filter= students.query("age>25 and gender == 'M'")
query_filter.head()
# Out:
#     id        name               nationality         city  latitude  \
# 83  83  Luke Davey  United States of America  Los Angeles     34.05
#
#     longitude gender  ethnic.group  age  english.grade  math.grade  \
# 83    -118.24      M           NaN   26            3.8         3.4
#
#     sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 83             3.7             5.0                 4                 5.0
#
#     refletter.rating
# 83                 3

# %% [markdown]
# # ***nlaargest and nsmallest***
#
# Use nlargest and nsmallest to get rows with the top or bottom values in a column

# %%
from IPython.display import display

# Get top 3 students with the highest grades in english
top_3_marks= students.nlargest(3, 'english.grade')
display(top_3_marks)

## Get 2 students with the lowest grades in english
bottom_2_marks= students.nsmallest(2, 'english.grade')
display(bottom_2_marks)
# Out:
#       id             name          nationality              city  latitude  \
# 15    15    Brittany Sath                Japan             Tokyo     35.69
# 68    68  Gabrielle Smith  Korea (Republic of)             Seoul     37.60
# 120  120    Meghan Arnold   Russian Federation  Saint Petersburg     59.89
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 15      139.75      F           NaN   21            4.0         3.9
# 68      126.98      F           NaN   23            4.0         3.0
# 120      30.26      F           NaN   24            4.0         3.9
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 15              3.7             3.0                 5                 3.0
# 68              2.8             3.0                 2                 2.0
# 120             3.3             3.0                 5                 3.0
#
#      refletter.rating
# 15                  5
# 68                  4
# 120                 3
#       id                    name               nationality     city  latitude  \
# 150  150  Abdul Jabbaar el-Abdul                     Egypt    Cairo     30.05
# 11    11            Sasha Jansen  United States of America  Chicago     41.85
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 150      31.25      M           NaN   20            1.5         3.5
# 11      -87.65      F           NaN   21            1.7         4.0
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 150             3.2             3.0                 3                 5.0
# 11              3.6             5.0                 4                 4.0
#
#      refletter.rating
# 150                 4
# 11                  5

# %% [markdown]
# # **Data Transformation and Mapping**
#
# - **apply:** allows us to apply a function to each element, row, or column in a DataFrame or Series
# - **map:** is used to map values in a Series according to a dictionary or another Series
# - **replace:** replace allows for replacing specific values in the DataFrame with new value
# - **astype:** this is used to convert data type
# - **pipe:** it allows chaining and using complex functions that operate on the entire DataFrame. This can be used for complex transformation operation

# %% [markdown]
# # ***Apply***

# %%
####adding column
# convert grades to scale of 100
import pandas as pd
students= pd.read_csv('data/student-dataset.csv')
students['mark_in_english']=students['english.grade'].apply(lambda grade: grade*20)
students.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 3             3.2             5.0                 5                 2.0
# 4             3.4             1.0                 4                 4.0
#
#    refletter.rating  mark_in_english
# 0                 4             70.0
# 1                 5             58.0
# 2                 4             78.0
# 3                 4             66.0
# 4                 5             74.0

# %% [markdown]
# # ***map***

# %%
import pandas as pd
students= pd.read_csv('data/student-dataset.csv')
students['gender']= students['gender'].map({'M':'Male','F':'Female'})
students['nationality']= students['nationality'].map({'Brazil':'Brazilian', 'China':'Chinese', 'United States of America':'American'})
students.head()
# Out:
#    id             name nationality                 city  latitude  longitude  \
# 0   0        Kiana Lor     Chinese               Suzhou     31.31     120.62
# 1   1   Joshua Lonaker    American        Santa Clarita     34.39    -118.54
# 2   2    Dakota Blanco    American              Oakland     37.80    -122.27
# 3   3  Natasha Yarusso    American        Castro Valley     37.69    -122.09
# 4   4   Brooke Cazares   Brazilian  São José dos Campos    -23.18     -45.88
#
#    gender  ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 0  Female           NaN   22            3.5         3.7             3.1
# 1    Male           NaN   22            2.9         3.2             3.6
# 2  Female           NaN   22            3.9         3.8             3.2
# 3  Female           NaN   20            3.3         2.8             3.2
# 4  Female           NaN   21            3.7         2.6             3.4
#
#    language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 0             1.0                 4                 4.0                 4
# 1             5.0                 5                 4.0                 5
# 2             5.0                 3                 3.0                 4
# 3             5.0                 5                 2.0                 4
# 4             1.0                 4                 4.0                 5

# %% [markdown]
# # ***replace***

# %%
# replace name 'Joshua Lonaker' with 'Joshu' (replace specific value)
students['name']= students['name'].replace({'Joshua Lonaker':'Joshu'})
students.head()
# Out:
#    id             name nationality                 city  latitude  longitude  \
# 0   0        Kiana Lor     Chinese               Suzhou     31.31     120.62
# 1   1            Joshu    American        Santa Clarita     34.39    -118.54
# 2   2    Dakota Blanco    American              Oakland     37.80    -122.27
# 3   3  Natasha Yarusso    American        Castro Valley     37.69    -122.09
# 4   4   Brooke Cazares   Brazilian  São José dos Campos    -23.18     -45.88
#
#    gender  ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 0  Female           NaN   22            3.5         3.7             3.1
# 1    Male           NaN   22            2.9         3.2             3.6
# 2  Female           NaN   22            3.9         3.8             3.2
# 3  Female           NaN   20            3.3         2.8             3.2
# 4  Female           NaN   21            3.7         2.6             3.4
#
#    language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 0             1.0                 4                 4.0                 4
# 1             5.0                 5                 4.0                 5
# 2             5.0                 3                 3.0                 4
# 3             5.0                 5                 2.0                 4
# 4             1.0                 4                 4.0                 5

# %% [markdown]
# # astype

# %%
# Convert 'english.grade' column to float

students['english.grade']= students['english.grade'].astype (int)

# Convert 'math.grade' column to string
students['math.grade']= students['math.grade'].astype (str)

students.head()
# Out:
#    id             name nationality                 city  latitude  longitude  \
# 0   0        Kiana Lor     Chinese               Suzhou     31.31     120.62
# 1   1            Joshu    American        Santa Clarita     34.39    -118.54
# 2   2    Dakota Blanco    American              Oakland     37.80    -122.27
# 3   3  Natasha Yarusso    American        Castro Valley     37.69    -122.09
# 4   4   Brooke Cazares   Brazilian  São José dos Campos    -23.18     -45.88
#
#    gender  ethnic.group  age  english.grade math.grade  sciences.grade  \
# 0  Female           NaN   22              3        3.7             3.1
# 1    Male           NaN   22              2        3.2             3.6
# 2  Female           NaN   22              3        3.8             3.2
# 3  Female           NaN   20              3        2.8             3.2
# 4  Female           NaN   21              3        2.6             3.4
#
#    language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 0             1.0                 4                 4.0                 4
# 1             5.0                 5                 4.0                 5
# 2             5.0                 3                 3.0                 4
# 3             5.0                 5                 2.0                 4
# 4             1.0                 4                 4.0                 5

# %% [markdown]
# # pipe

# %%
def calculate_final_grades(df):
    df['final_grades']= (df['english.grade'].astype(float) +df['math.grade'].astype(float) + df['sciences.grade']+ df['language.grade'] ) / 4
    return df
students= students.pipe(calculate_final_grades)
students.tail()         #last 5 items
# Out:
#       id               name nationality         city  latitude  longitude  \
# 302  302        Austin Haas    American     Columbus     39.96     -83.00
# 303  303    Madison Fithian    American  Los Angeles     34.05    -118.24
# 304  304  Zachary Mulvahill    American  Los Angeles     34.05    -118.24
# 305  305   Eliana Michelsen    American      Oakland     37.80    -122.27
# 306  306    Dane Whittemore         NaN      Toronto     43.67     -79.42
#
#      gender  ethnic.group  age  english.grade math.grade  sciences.grade  \
# 302    Male           NaN   20              3        3.7             3.1
# 303  Female           NaN   20              3        3.9             4.0
# 304    Male           NaN   20              3        3.4             3.9
# 305  Female           NaN   23              3        2.8             2.9
# 306    Male           NaN   21              3        3.2             4.0
#
#      language.grade  portfolio.rating  coverletter.rating  refletter.rating  \
# 302             5.0                 4                 5.0                 5
# 303             5.0                 5                 5.0                 3
# 304             5.0                 5                 5.0                 3
# 305             5.0                 4                 4.0                 5
# 306             5.0                 5                 4.0                 5
#
#      final_grades
# 302         3.700
# 303         3.975
# 304         3.825
# 305         3.425
# 306         3.800

# %% [markdown]
# # Data Cleaning and Manipulation
#
# - Handle Missing Data
# - Handle Duplicates
# - One-Hot-Encoding
# - Normalization

# %% [markdown]
# # Handle Missing Data
#
# - Remove Rows Containing Missing Values (df.dropna())
#
#     - dropna(axis=0) removes rows containing at least one missing value
#     - (dropna(axis=1)) Removes columns containing at least one missing value
#
# - Replace Missing Values (df.fillna())
#
#     - **Replace with specific value:** (df.fillna(value))
#
#     - **Backward Fill, Forward Fill:** (df.fillna(value, method='bfill')) (df.fillna(value, method='ffill'))
#
#     - **Fill individual column with specified value:** (df.fillna({'height': 150, 'weight':60}))
#
#     - **Fill with average, Interpolation etc.**

# %%
from IPython.display import display

students= pd.read_csv('data/student-dataset.csv')
display(students.head())
students.dropna(axis=0, how='any', inplace=True) # (axis=0 default) drop rows with NaN

students=students.fillna (1)    #replace missing values with 1
display (students.head())

students.fillna(method='ffill')  # fill with previous row value
students. fillna(method='bfill') # fill with next row

students['english.grade'].fillna(50) #only fill empty value of Name column

students.fillna({'english.grade':50, 'gender': 'M'}) # replace mark with 50 if its empty and gender with

df_interpolated=students.interpolate()

students.fillna(df_interpolated)
students['english.grade'].fillna(students['english.grade'].mean())
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 3             3.2             5.0                 5                 2.0
# 4             3.4             1.0                 4                 4.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
# 3                 4
# 4                 5
# Empty DataFrame
# Columns: [id, name, nationality, city, latitude, longitude, gender, ethnic.group, age, english.grade, math.grade, sciences.grade, language.grade, portfolio.rating, coverletter.rating, refletter.rating]
# Index: []
# C:\Users\user\AppData\Local\Temp\ipykernel_17272\2998074336.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students.fillna(method='ffill')  # fill with previous row value
# C:\Users\user\AppData\Local\Temp\ipykernel_17272\2998074336.py:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students. fillna(method='bfill') # fill with next row
# Series([], Name: english.grade, dtype: float64)

# %%
from IPython.display import display
import pandas as pd

students = pd.read_csv('data/student-dataset.csv')
display(students.head())  

# Remove rows with any missing values
students.dropna(axis=0, how='any', inplace=True)  

# Replace remaining missing values with 1
students = students.fillna(1)  
display(students.head())
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
# 2             3.2             5.0                 3                 3.0
# 3             3.2             5.0                 5                 2.0
# 4             3.4             1.0                 4                 4.0
#
#    refletter.rating
# 0                 4
# 1                 5
# 2                 4
# 3                 4
# 4                 5
# Empty DataFrame
# Columns: [id, name, nationality, city, latitude, longitude, gender, ethnic.group, age, english.grade, math.grade, sciences.grade, language.grade, portfolio.rating, coverletter.rating, refletter.rating]
# Index: []

# %% [markdown]
# # Handle Duplicate Data
#
# - Check Duplicates
# - Drop Duplicates

# %%
duplicates= students.duplicated()   #check duplicate
students.drop_duplicates()      #drop duplicates
duplicates
# Out:
# Series([], dtype: bool)

# %% [markdown]
# # One-Hot-Encoding
#
# - One Hot Encoding is a method for converting categorical variables into a binary format. It creates new binary columns (0s and 1s) for each category in the original variable. Each category in the original column is represented as a separate column, where a value of 1 indicates the presence of that category, and 0 indicates its absence For example we replace the country name with numerical value e.g. America = 1 India=2 Nepal=3

# %% [markdown]
# # Data Normalization
#
# - Data normalization involves adjusting measurement values of different scales to a common scale. Normalization is only applicable to numerical columns
#
# There are five common normalization methods:
#
# 1. Single feature scaling
#
# 2. Min-max scaling
#
# 3. Z-score normalization
#
# 4. Log scaling
#
# 5. Clipping

# %%
import numpy as np
salt= np.log(30)
gold= np.log(150000)
print(salt,gold)
# Out:
# 3.4011973816621555 11.918390573078392

# %% [markdown]
# # Single Feature Scaling
#
# - Single feature scaling transforms each value in a column into a number between 0 and 1
#
# # Min-Max Scaling
#
# - This scales the data to a specific range typically [0, 1]. The formula is: x_new = x-min(x)/(max(x)-min(x))
#
# # Z-score Normalization
#
# - This normalization method transforms the data so that it has a mean of 0 and a standard deviation of 1.
# x_new= (x-µ)/σ
# where:µ=mean and σ= SD
#
# # Log Scaling
# - This method uses the logarithm to scale the data, which is useful when dealing with data that has a large range or is heavily skewed
#
# x_new = log(x+1)
#
# # Clipping
#
# - It is a technique to limit the range of data by setting lower and upper boundss. It is useful for handling outliers.

# %%
import numpy as np
import pandas as pd
products = pd.read_csv('data/product-data.csv')
display(products.head())
#Single Feature Scaling
products['Sales_Single_Scale'] = products['Sales']/ products['Sales'].max()
#log 
products['Sales_log_Scale'] = np.log1p(products['Sales'])

# clipping
products['Discount_Clipped']= products['Discount_Percentage'].clip(lower=5, upper=15)

products.head()
# Out:
#    Product_ID  Sales  Price  Customer_Rating  Discount_Percentage
# 0           1    500    200              4.2                   10
# 1           2    700    450              3.9                   15
# 2           3    800    300              4.5                   12
# 3           4    900    350              4.8                    8
# 4           5   1000    500              4.0                    5
#    Product_ID  Sales  Price  Customer_Rating  Discount_Percentage  \
# 0           1    500    200              4.2                   10
# 1           2    700    450              3.9                   15
# 2           3    800    300              4.5                   12
# 3           4    900    350              4.8                    8
# 4           5   1000    500              4.0                    5
#
#    Sales_Single_Scale  Sales_log_Scale  Discount_Clipped
# 0                 0.5         6.216606                10
# 1                 0.7         6.552508                15
# 2                 0.8         6.685861                12
# 3                 0.9         6.803505                 8
# 4                 1.0         6.908755                 5

# %% [markdown]
# # Grouping & Aggregate
#
# - Grouping consists of three operations
#     - Split
#     - Apply
#     - Combine

# %%
import numpy as np
import pandas as pd

students = pd.read_csv('data/student-dataset.csv')

# group data based on Gender

gender_data = students.groupby('gender')

display (gender_data.count())

gender_data['english.grade'].mean() 

# standard deviation (std())

group_by_nationality = students.groupby('nationality')

display("Best_in_math:",group_by_nationality['math.grade'].mean())
# Out:
#          id  name  nationality  city  latitude  longitude  ethnic.group  age  \
# gender
# F       152   152          152   152       152        152             0  152
# M       151   151          151   151       151        151             0  151
# other     4     4            4     4         4          4             0    4
#
#         english.grade  math.grade  sciences.grade  language.grade  \
# gender
# F                 152         152             152             152
# M                 151         151             151             151
# other               4           4               4               4
#
#         portfolio.rating  coverletter.rating  refletter.rating
# gender
# F                    152                 152               152
# M                    151                 151               151
# other                  4                   4                 4
# 'Best_in_math:'
# nationality
# Bangladesh                  3.900000
# Brazil                      3.377778
# Canada                      3.014286
# Chile                       3.700000
# China                       3.784615
# Colombia                    3.580000
# Cuba                        2.800000
# Dominican Republic          3.800000
# Egypt                       3.500000
# El Salvador                 2.900000
# Germany                     3.500000
# India                       3.275000
# Japan                       3.538462
# Korea (Republic of)         3.066667
# Mexico                      3.387500
# Morocco                     3.600000
# Myanmar                     3.400000
# Netherlands                 3.500000
# Nicaragua                   3.700000
# Pakistan                    2.933333
# Peru                        3.100000
# Philippines                 3.600000
# Poland                      3.800000
# Russian Federation          3.383333
# Spain                       3.750000
# Thailand                    3.900000
# Tunisia                     3.100000
# Turkey                      2.700000
# Ukraine                     3.300000
# United Kingdom              3.150000
# United States of America    3.417098
# Name: math.grade, dtype: float64

# %% [markdown]
# # Aggregation
#
# - count() - Number of non-null observations
#
# - sum() - Sum of values
#
# - mean() - Mean of values
#
# - median() - Arithmetic median of values
#
# - min() - Minimum
#
# - max() - Maximum
#
# - mode() - Mode
#
# - std() - Standard deviation
#
# - var() - Variance

# %% [markdown]
# # Sorting
#
# **Sort By index**
#
# **Sort By Value**
# - Ascending
# - Descending
# - Sorting by Date
# - Sorting with key Function

# %%
# Sort by name
students= pd.read_csv('data/student-dataset.csv')
new_sorted_data= students.sort_values(by=['name'],ascending=False)
display(new_sorted_data.head())

# sort by math grade
students.sort_values(by= ['math.grade', 'english.grade'], ascending= False, inplace=True)
students.head()
# Out:
#       id               name               nationality         city  latitude  \
# 47    47           Zoe Kern  United States of America  West Jordan     40.61
# 175  175  Zahraaa el-Yousef                     India       Hospet     15.27
# 259  259  Zaghlool al-Pasha                     India       Deoria     26.50
# 304  304  Zachary Mulvahill  United States of America  Los Angeles     34.05
# 52    52    Zachary Bradley                     Spain       Madrid     40.41
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 47     -111.94      F           NaN   22            2.1         4.0
# 175      76.40      F           NaN   22            3.9         3.7
# 259      83.79      M           NaN   21            2.3         3.8
# 304    -118.24      M           NaN   20            3.2         3.4
# 52       -3.69      M           NaN   21            3.5         3.5
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 47              3.4             5.0                 4                 5.0
# 175             3.8             4.0                 4                 4.0
# 259             3.8             4.0                 5                 5.0
# 304             3.9             5.0                 5                 5.0
# 52              3.4             2.0                 3                 5.0
#
#      refletter.rating
# 47                  4
# 175                 4
# 259                 5
# 304                 3
# 52                  5
#       id                 name               nationality         city  \
# 286  286      Michael Griffin  United States of America     New York
# 122  122          Wesley Nunn  United States of America  Los Angeles
# 290  290  Michaela Schoenbeck  United States of America      Rexburg
# 294  294       Matthew Obourn  United States of America    San Diego
# 37    37        Katrina Saito                     Japan        Tokyo
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 286     40.71     -74.01      M           NaN   21            4.0         4.0
# 122     34.05    -118.24      M           NaN   23            3.9         4.0
# 290     43.83    -111.79      F           NaN   22            3.9         4.0
# 294     32.72    -117.16      M           NaN   23            3.9         4.0
# 37      35.69     139.75      F           NaN   22            3.8         4.0
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 286             4.0             5.0                 3                 5.0
# 122             2.1             5.0                 5                 5.0
# 290             3.3             5.0                 5                 4.0
# 294             3.9             5.0                 4                 4.0
# 37              3.7             4.0                 5                 4.0
#
#      refletter.rating
# 286                 5
# 122                 3
# 290                 4
# 294                 4
# 37                  5

# %%
data= pd.read_csv('data/student-admission.csv')

#convert to datetime

data ['AdmissionDate'] = pd.to_datetime (data ['AdmissionDate'])

#sort by AdminssionDate

sorted_by_date= data.sort_values(by=['AdmissionDate', 'Name'], ascending= True)

sorted_by_date
# Out:
#    Unnamed: 0 AdmissionDate  StudentID     Name      Stream
# 5           5    2021-01-17          1  Abhinav          IT
# 3           3    2021-01-18          2    Sohan  Mechanical
# 2           2    2021-01-20          3    Mohan       Civil
# 6           6    2021-01-21          4    Danny         EEE
# 4           4    2021-01-22          6    Lucky         CSE
# 1           1    2021-01-22          5    Shyam         ECE
# 0           0    2021-01-25          7      Ram         CSE

# %%
import pandas as pd
import matplotlib.pyplot as plt

students = pd.read_csv('data/student-dataset.csv')

# Visualization: Plotting the sorted math and english grades
plt.figure(figsize=(10,6))
plt.bar(students['name'].head(9), students['math.grade'].head(9), color='aqua', label='Math Grades')
plt.xlabel('Student Name')
plt.ylabel('Grades')
plt.title('Top 5 Sorted Math and English Grades by Student')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
